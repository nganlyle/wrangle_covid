# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
# Import the data 
ltc = pd.read_csv('../data/BC/ngan_merged_OSAtoCOVID.csv')
ltc.info()
ltc.columns.values
# for each in ltc.columns.values:
#     print(each)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Columns: 108 entries, FACILITY_NAME to outbreak
# dtypes: float64(24), int64(7), object(77)
# memory usage: 250.7+ KB
# array(['FACILITY_NAME', 'HCC_CODE', 'HLTH_AUTH', 'OWNERSHIP',
#        'STREET_ADDRESS', 'CITY', 'POSTAL', 'PHONE', 'OPERATOR_NAME',
#        'OPEN_DATE', 'COUNCIL', 'MEETINGS_HELD', 'PARKING_COSTS',
#        'REGULATION', 'ACCRED_STATUS', 'ACCRED_EXPIRY',
#        'COMPLAINT_CONTACT', 'COMPLAINT_PHONE', 'SPENDING_ACCOUNT',
#        'FOOD_SERVICE', 'FOOD_PREP', 'FOOD_COST_LASTYR',
#        'FOOD_COST_CURRENTYR', 'LANGUAGES', 'DCH_NURSE_LASTYR',
#        'DCH_ALLIED_LASTYR', 'DCH_TOTAL_LASTYR', 'DCH_NURSE_CURRENTYR',
#        'DCH_ALLIED_CURRENTYR', 'DCH_TOTAL_CURRENTYR', 'FEES_CABLE',
#        'FEES_TELE', 'FEES_INTERNET', 'FEES_OTHER', 'BEDS_PRIVATE',
#        'BEDS_PUBLIC', 'BEDS_TOTAL', 'ROOMS_PRIVATE', 'ROOMS_SEMI',
#        'ROOMS_MULTI', 'COMPLAINTS', 'SUB_COMPLAINTS', 'INCIDENT_OUTBREAK',
#        'INCIDENT_ABUSE', 'INCIDENT_FALL', 'INCIDENT_POISON',
#        'INCIDENT_MEDICATION', 'INCIDENT_WANDERING', 'INCIDENT_INJURY',
#        'INCIDENT_AGGRESSION', 'INCIDENT_OUTBREAK_100',
#        'INCIDENT_ABUSE_100', 'INCIDENT_FALL_100', 'INCIDENT_POISON_100',
#        'INCIDENT_MEDICATION_100', 'INCIDENT_WANDERING_100',
#        'INCIDENT_INJURY_100', 'INCIDENT_AGGRESSION_100', 'ADVERSE_EVENT',
#        'AGE', 'FEMALE', 'AGE_85_PLUS', 'AGE_UNDER_65', 'STAY_LENGTH',
#        'DEPRESSION', 'ADL_DEPENDENT', 'CPS_SEVERE', 'DEMENTIA',
#        'ABS_PHYS_ABUSIVE', 'ISE', 'ISE_LOW', 'CMI', 'THERAPY_PT',
#        'THERAPY_RT', 'THERAPY_OT', 'MEDS_DEPRESSION',
#        'MEDS_ANTIPSYCHOTICS', 'RESTRAINTS', 'WEBPAGE', 'SURVEY_URL',
#        'MISSING_SURVEY', 'CONTRACTED_NURSING', 'CONTRACTED_CARE_AIDES',
#        'CONTRACTED_HOUSEKEEPING', 'CONTRACTED_PLANT', 'PER_DIEM_LASTYR',
#        'PER_DIEM_CURRENTYR', 'INSPECTIONS', 'INFRACTIONS',
#        'INFRACTIONS_LICENSING', 'INFRACTIONS_FACILITY',
#        'INFRACTIONS_STAFFING', 'INFRACTIONS_POLICY', 'INFRACTIONS_CARE',
#        'INFRACTIONS_DISEASE', 'INFRACTIONS_FOOD',
#        'INFRACTIONS_MEDICATION', 'INFRACTIONS_PROGRAM',
#        'INFRACTIONS_REPORTING', 'INFRACTIONS_RIGHTS', 'INFRACTIONS_OTHER',
#        'latitude', 'longitude', 'cleaned_name', 'Facility Name',
#        'Total Confirmed Cases', 'Total Deaths', 'outbreak'], dtype=object)

# %%
# There are 5 homes where all ROOMS_* preditors == 0
temp = ltc.loc[ltc['ROOMS_PRIVATE'] == 0]
temp[['FACILITY_NAME', 'BEDS_PRIVATE', 'BEDS_TOTAL', 'ROOMS_PRIVATE', 'ROOMS_SEMI', 'ROOMS_MULTI']]
# Out:
#                               FACILITY_NAME  BEDS_PRIVATE  BEDS_TOTAL  \
# 26   Brookhaven Care Centre                  0             84
# 66   Dufferin Care Centre                    25            153
# 101  Glenmore Lodge                          18            118
# 107  Haida Gwaii Hospital and Health Centre  0             8
# 123  Holyrood Manor                          2             125
# 181  Nicola Lodge                            18            230
#
#      ROOMS_PRIVATE  ROOMS_SEMI  ROOMS_MULTI
# 26   0              0           0
# 66   0              0           0
# 101  0              0           0
# 107  0              2           2
# 123  0              0           0
# 181  0              0           0

# %% [markdown]
# # Impute where all ROOMS_* predictors == 0
#
# The blank room counts are due to the self-reported nature of the data. In these cases, the facilities did not respond for our currently published Quick Facts Directory. They DID respond, however, to our recent targeted inquiries to resolve room count issues mentioned above.
#     - Brookhaven Care Centre – 104 public beds, 96 single rooms, 4 double rooms
#     - Dufferin Care Centre – 128 public beds, 25 private beds, 97 single rooms, 28 double rooms
#     - Glenmore Lodge – 100 public beds, 18 private beds, 118 single rooms
#     - Holyrood Manor – 124 public beds, 1 private bed, 77 single rooms, 24 double rooms
#     - Nicola Lodge – 212 public beds, 18 private beds, 220 single rooms, 5 double rooms

# %%
# Impute
# Brookhaven Care Centre
ltc.at[26, 'BEDS_TOTAL'] = 104
ltc.at[26, 'ROOMS_PRIVATE'] = 97
ltc.at[26, 'ROOMS_SEMI'] = 28

# ltc.loc[ltc['FACILITY_NAME'] == 'Dufferin Care Centre'] #66
ltc.at[66, 'ROOMS_PRIVATE'] = 96
ltc.at[66, 'ROOMS_SEMI'] = 4

# ltc.loc[ltc['FACILITY_NAME'] == 'Glenmore Lodge'] #101
ltc.at[101, 'ROOMS_PRIVATE'] = 118

# ltc.loc[ltc['FACILITY_NAME'] == 'Holyrood Manor'] #123
ltc.at[123, 'BEDS_TOTAL'] = 125
ltc.at[123, 'BEDS_PRIVATE'] = 1
ltc.at[123, 'ROOMS_PRIVATE'] = 77
ltc.at[123, 'ROOMS_SEMI'] = 24

# ltc.loc[ltc['FACILITY_NAME'] == 'Nicola Lodge'] #181
ltc.at[181, 'ROOMS_PRIVATE'] = 220
ltc.at[181, 'ROOMS_SEMI'] = 5

# %%
ls = ['Brookhaven Care Centre',
    'Dufferin Care Centre',
    'Glenmore Lodge',
    'Holyrood Manor',
    'Nicola Lodge'
]

temp = ltc.loc[ltc['FACILITY_NAME'].isin(ls)]
temp[['FACILITY_NAME', 'BEDS_PRIVATE', 'BEDS_TOTAL', 'ROOMS_PRIVATE', 'ROOMS_SEMI', 'ROOMS_MULTI']]
# Out:
#               FACILITY_NAME  BEDS_PRIVATE  BEDS_TOTAL  ROOMS_PRIVATE  \
# 26   Brookhaven Care Centre  0             104         97
# 66   Dufferin Care Centre    25            153         96
# 101  Glenmore Lodge          18            118         118
# 123  Holyrood Manor          1             125         77
# 181  Nicola Lodge            18            230         220
#
#      ROOMS_SEMI  ROOMS_MULTI
# 26   28          0
# 66   4           0
# 101  0           0
# 123  24          0
# 181  5           0

# %%
# def missing(dff):
#     print (round((dff.isnull().sum() * 100/ len(dff)),2).sort_values(ascending=False))

# missing(ltc)

# %%
# Convert all suppressed values to NA
ltc = ltc.replace('suppressed', np.nan, regex=True)

# Convert NA values in the 'Total Confirmed Cases', 'Total Deaths' columns to 0s
ltc["Total Confirmed Cases"].fillna(0, inplace = True)
ltc["Total Deaths"].fillna(0, inplace = True)

# %% [markdown]
# # Special Unit homes
#
# - The British Columbia Long-Term Care Quick Facts Directory contains information on 294 Long-term care facilities
# - Three facilities have special care units identified in the Directory with a separate data. These are not normally counted as separate facilities.
#     - Berkley Care Centre - Special Unit
#     - Fair Haven - Vancouver - Special Unit
#     - Harmony Court Care Centre - Special Unit
# - Special Units **do not** have complaints, incident or inspections/infractions data
# - Special Units **do** have different values for **HCC_CODE, open_date, DCH, number of beds and demographic data**
# - Special care units are not counted separately in overall facility counts, they are counted separately for this direct care hours analysis.
#
#
# ### Possible Actions
# 1. Remove 3 Special Units
# 2. **Merge Special Unit Homes with their parent home**
#     - Weighted average (by number of beds) of:
#         - DCH
#         - Case mix
#             - Age, Female, AGE_85_PLUS, AGE_UNDER_65, STAY_LENGTH
#             - DEPRESSION, ADL_DEPENDENT, CPS_SEVERE, DEMENTIA, ABS_PHYS_ABUSIVE
#             - ISE, ISE_LOW, CMI, THERAPY_PT, THERAPY_RT, THERAPY_OT
#         - Quality
#             - MEDS_DEPRESSION, MEDS_ANTIPSYCHOTICS, RESTRAINTS
#     - Sum number beds/rooms
#         - 'BEDS_TOTAL', 'ROOMS_PRIVATE', 'ROOMS_SEMI', 'ROOMS_MULTI'
#         - 'BEDS_PRIVATE', 'BEDS_PUBLIC', 'Total Confirmed Cases', 'Total Deaths'
#     - Keep complaints, incident and inspections/infractions etc. data from parent home

# %%
ltc[ltc.FACILITY_NAME.str.contains("Special Unit", na=False)]
# Out:
#                                  FACILITY_NAME HCC_CODE  \
# 16   Berkley Care Centre - Special Unit         93A60
# 82   Fair Haven - Vancouver - Special Unit      93860
# 110  Harmony Court Care Centre  - Special Unit  93A2A
#
#                     HLTH_AUTH OWNERSHIP       STREET_ADDRESS             CITY  \
# 16   Vancouver Coastal Health  HA        2444 Burr Place      North Vancouver
# 82   Vancouver Coastal Health  PNP       2720 East 48th Ave.  Vancouver
# 110  Fraser Health             PFP       7195 Canada Way      Burnaby
#
#      POSTAL           PHONE                           OPERATOR_NAME OPEN_DATE  \
# 16   V7H3A5  (604) 924-8300  Vancouver Coastal Health                1998
# 82   V5S1G7  (604) 433-2939  Fair Haven United Church Homes Society  1979
# 110  V5E3R7  (604) 527-3300  Age Care Investment Ltd.                2011
#
#                               COUNCIL     MEETINGS_HELD PARKING_COSTS  \
# 16   Resident Council, Family Council  Regular Schedule  Yes (no fee)
# 82   Resident Council, Family Council  Regular Schedule  Yes (no fee)
# 110  Family Council                    Regular Schedule  Yes (no fee)
#
#                                REGULATION ACCRED_STATUS   ACCRED_EXPIRY  \
# 16   Community Care & Assisted Living Act  Accredited    September 2020
# 82   Community Care & Assisted Living Act  Accredited    November 2022
# 110  Community Care & Assisted Living Act  Unknown       not available
#
#                       COMPLAINT_CONTACT               COMPLAINT_PHONE  \
# 16   Manager                             (604) 924-8356
# 82   Clinical Nurse Manager              (604) 433-2939x2232 or x2222
# 110  General Manager / Director of Care  (604) 527-3300
#
#     SPENDING_ACCOUNT        FOOD_SERVICE FOOD_PREP FOOD_COST_LASTYR  \
# 16   Yes              Operator            Yes       $7.95
# 82   Yes              Operator            Yes       $7.60
# 110  Yes              Outside Contractor  Yes       $3.92
#
#     FOOD_COST_CURRENTYR  \
# 16   $8.11
# 82   $8.08
# 110  $5.21
#
#                                                                                                                                                          LANGUAGES  \
# 16   English, Tagalog, Spanish, Korean, Cantonese, Mandarin, Greek, Romanian, Khmer, Gujarati, Slovene, Hindi, Punjabi, Serbian, Bengali, Polish, Russian, Italian
# 82   NaN
# 110  English, French, Thai, Greek, Cantonese, Persian, Mandarin, Hindi, Spanish, Italian, Vietnamese, Hungarian, Tagalog, Punjabi, Farsi, Patwah
#
#      DCH_NURSE_LASTYR  DCH_ALLIED_LASTYR  DCH_TOTAL_LASTYR  \
# 16   3.26              0.24               3.50
# 82   3.95              0.23               4.18
# 110  1.99              0.08               2.07
#
#      DCH_NURSE_CURRENTYR  DCH_ALLIED_CURRENTYR  DCH_TOTAL_CURRENTYR  \
# 16   3.26                 0.24                  3.50
# 82   3.95                 0.23                  4.18
# 110  1.99                 0.27                  2.27
#
#     FEES_CABLE FEES_TELE FEES_INTERNET  \
# 16   No         No        No
# 82   No         No        No
# 110  No         No        No
#
#                                                         FEES_OTHER  \
# 16   Clothing labelling fee
# 82   Clothing labelling fee, specialized wheelchairs, hairdressing
# 110  NaN
#
#      BEDS_PRIVATE  BEDS_PUBLIC  BEDS_TOTAL  ROOMS_PRIVATE  ROOMS_SEMI  \
# 16   0             12           12          12             0
# 82   0             19           19          19             0
# 110  0             25           25          25             0
#
#      ROOMS_MULTI COMPLAINTS SUB_COMPLAINTS INCIDENT_OUTBREAK INCIDENT_ABUSE  \
# 16   0            NaN        NaN            NaN               NaN
# 82   0            NaN        NaN            NaN               NaN
# 110  0            NaN        NaN            NaN               NaN
#
#     INCIDENT_FALL INCIDENT_POISON INCIDENT_MEDICATION INCIDENT_WANDERING  \
# 16   NaN           NaN             NaN                 NaN
# 82   NaN           NaN             NaN                 NaN
# 110  NaN           NaN             NaN                 NaN
#
#     INCIDENT_INJURY INCIDENT_AGGRESSION INCIDENT_OUTBREAK_100  \
# 16   NaN             NaN                 NaN
# 82   NaN             NaN                 NaN
# 110  NaN             NaN                 NaN
#
#     INCIDENT_ABUSE_100 INCIDENT_FALL_100 INCIDENT_POISON_100  \
# 16   NaN                NaN               NaN
# 82   NaN                NaN               NaN
# 110  NaN                NaN               NaN
#
#     INCIDENT_MEDICATION_100 INCIDENT_WANDERING_100 INCIDENT_INJURY_100  \
# 16   NaN                     NaN                    NaN
# 82   NaN                     NaN                    NaN
# 110  NaN                     NaN                    NaN
#
#     INCIDENT_AGGRESSION_100   ADVERSE_EVENT AGE FEMALE AGE_85_PLUS  \
# 16   NaN                     not applicable  78  39.7%  13.8%
# 82   NaN                     not applicable  80  27.5%  29.7%
# 110  NaN                     not applicable  84  87.2%  56.9%
#
#     AGE_UNDER_65 STAY_LENGTH DEPRESSION ADL_DEPENDENT CPS_SEVERE DEMENTIA  \
# 16   13.8%        317         30.0%      18.0%         70.0%      86.0%
# 82   1.4%         273         7.8%       19.5%         66.2%      85.7%
# 110  4.6%         705         13.6%      0.0%          1.0%       95.1%
#
#     ABS_PHYS_ABUSIVE  ISE ISE_LOW   CMI THERAPY_PT THERAPY_RT THERAPY_OT  \
# 16   32.0%            1.5  70.0%   0.53  0.0%       50.0%      0.0%
# 82   19.5%            2.0  58.4%   0.54  1.3%       59.7%      0.0%
# 110  1.9%             2.7  50.5%   0.44  1.9%       41.7%      0.0%
#
#     MEDS_DEPRESSION MEDS_ANTIPSYCHOTICS RESTRAINTS  \
# 16   84.0%           71.3%               21.7%
# 82   76.6%           75.4%               9.1%
# 110  35.0%           31.0%               0.0%
#
#                                                          WEBPAGE  \
# 16   http://www.vch.ca/locations-services/result?res_id=36
# 82   http://www.fairhaven.bc.ca/care/
# 110  http://www.agecare.ca/community/agecare-harmony-court/care/
#
#                                                                                         SURVEY_URL  \
# 16   https://surveybcseniors.org/carehomeresults/kiwanis-care-centre-vcha/
# 82   https://surveybcseniors.org/carehomeresults/the-fair-haven-united-church-home-vancouver-vcha/
# 110  https://surveybcseniors.org/carehomeresults/harmony-court-care-centre-fha/
#
#     MISSING_SURVEY CONTRACTED_NURSING CONTRACTED_CARE_AIDES  \
# 16   NaN            No                 No
# 82   NaN            No                 No
# 110  NaN            Yes                Yes
#
#     CONTRACTED_HOUSEKEEPING CONTRACTED_PLANT PER_DIEM_LASTYR  \
# 16   Yes                     No               NaN
# 82   No                      No               $281.61
# 110  Yes                     No               $171.17
#
#     PER_DIEM_CURRENTYR  INSPECTIONS  INFRACTIONS  INFRACTIONS_LICENSING  \
# 16   NaN               NaN          NaN          NaN
# 82   $272.35           NaN          NaN          NaN
# 110  $182.33           NaN          NaN          NaN
#
#      INFRACTIONS_FACILITY  INFRACTIONS_STAFFING  INFRACTIONS_POLICY  \
# 16  NaN                   NaN                   NaN
# 82  NaN                   NaN                   NaN
# 110 NaN                   NaN                   NaN
#
#      INFRACTIONS_CARE  INFRACTIONS_DISEASE  INFRACTIONS_FOOD  \
# 16  NaN               NaN                  NaN
# 82  NaN               NaN                  NaN
# 110 NaN               NaN                  NaN
#
#      INFRACTIONS_MEDICATION  INFRACTIONS_PROGRAM  INFRACTIONS_REPORTING  \
# 16  NaN                     NaN                  NaN
# 82  NaN                     NaN                  NaN
# 110 NaN                     NaN                  NaN
#
#      INFRACTIONS_RIGHTS  INFRACTIONS_OTHER   latitude   longitude  \
# 16  NaN                 NaN                 49.141596 -122.905427
# 82  NaN                 NaN                 49.225452 -123.036584
# 110 NaN                 NaN                 49.253409 -122.989119
#
#                                   cleaned_name Facility Name  \
# 16   berkley care centre - special unit         NaN
# 82   fair haven - vancouver - special unit      NaN
# 110  harmony court care centre  - special unit  NaN
#
#      Total Confirmed Cases  Total Deaths  outbreak
# 16   0.0                    0.0           0
# 82   0.0                    0.0           0
# 110  0.0                    0.0           0

# %%
# Convert variables to numeric type
ls = [
      'AGE', 'FEMALE', 'AGE_85_PLUS', 'AGE_UNDER_65', 'STAY_LENGTH',
      'DEPRESSION', 'ADL_DEPENDENT', 'CPS_SEVERE', 'DEMENTIA',
      'ABS_PHYS_ABUSIVE', 'ISE', 'ISE_LOW', 'CMI', 'THERAPY_PT',
      'THERAPY_RT', 'THERAPY_OT', 'MEDS_DEPRESSION',
      'MEDS_ANTIPSYCHOTICS', 'RESTRAINTS',
   'COMPLAINTS', 'SUB_COMPLAINTS', 'INCIDENT_OUTBREAK',
   'INCIDENT_ABUSE', 'INCIDENT_FALL', 'INCIDENT_POISON',
   'INCIDENT_MEDICATION', 'INCIDENT_WANDERING', 'INCIDENT_INJURY',
   'INCIDENT_AGGRESSION', 'INCIDENT_OUTBREAK_100',
   'INCIDENT_ABUSE_100', 'INCIDENT_FALL_100', 'INCIDENT_POISON_100',
   'INCIDENT_MEDICATION_100', 'INCIDENT_WANDERING_100',
   'INCIDENT_INJURY_100', 'INCIDENT_AGGRESSION_100', 'ADVERSE_EVENT'
]

for each in ls:
    ltc[each] = ltc[each].astype(str).str.rstrip('%')
    ltc[each] = pd.to_numeric(ltc[each], errors='coerce')

# %%
ltc[ltc['FACILITY_NAME'].str.contains('Fair Haven', regex=False, na=False)]
# Out:
#                             FACILITY_NAME HCC_CODE                 HLTH_AUTH  \
# 80  Fair Haven - Burnaby                   99C49    Fraser Health
# 81  Fair Haven - Vancouver                 999HG    Vancouver Coastal Health
# 82  Fair Haven - Vancouver - Special Unit  93860    Vancouver Coastal Health
#
#    OWNERSHIP       STREET_ADDRESS       CITY  POSTAL           PHONE  \
# 80  PNP       7557 Sussex Ave.     Burnaby    V5J3V6  (604) 435-0525
# 81  PNP       2720 East 48th Ave.  Vancouver  V5S1G7  (604) 433-2939
# 82  PNP       2720 East 48th Ave.  Vancouver  V5S1G7  (604) 433-2939
#
#                              OPERATOR_NAME OPEN_DATE  \
# 80  Fair Haven Homes Society                1994
# 81  Fair Haven United Church Homes Society  1979
# 82  Fair Haven United Church Homes Society  1979
#
#                              COUNCIL     MEETINGS_HELD      PARKING_COSTS  \
# 80  Resident Council, Family Council  Regular Schedule  Yes (fee charged)
# 81  Resident Council, Family Council  Regular Schedule  Yes (no fee)
# 82  Resident Council, Family Council  Regular Schedule  Yes (no fee)
#
#                               REGULATION ACCRED_STATUS  ACCRED_EXPIRY  \
# 80  Community Care & Assisted Living Act  Accredited    November 2022
# 81  Community Care & Assisted Living Act  Accredited    November 2022
# 82  Community Care & Assisted Living Act  Accredited    November 2022
#
#          COMPLAINT_CONTACT               COMPLAINT_PHONE SPENDING_ACCOUNT  \
# 80  Nurse Manager           (604) 435-0525x304 or x320    Yes
# 81  Clinical Nurse Manager  (604) 433-2939x2232 or x2222  Yes
# 82  Clinical Nurse Manager  (604) 433-2939x2232 or x2222  Yes
#
#    FOOD_SERVICE FOOD_PREP FOOD_COST_LASTYR FOOD_COST_CURRENTYR LANGUAGES  \
# 80  Operator     Yes       $7.48            $7.53               NaN
# 81  Operator     Yes       $7.70            $7.98               NaN
# 82  Operator     Yes       $7.60            $8.08               NaN
#
#     DCH_NURSE_LASTYR  DCH_ALLIED_LASTYR  DCH_TOTAL_LASTYR  \
# 80  2.67              0.33               3.00
# 81  2.70              0.23               2.93
# 82  3.95              0.23               4.18
#
#     DCH_NURSE_CURRENTYR  DCH_ALLIED_CURRENTYR  DCH_TOTAL_CURRENTYR FEES_CABLE  \
# 80  2.74                 0.34                  3.08                 No
# 81  2.85                 0.23                  3.08                 No
# 82  3.95                 0.23                  4.18                 No
#
#    FEES_TELE FEES_INTERNET  \
# 80  No        No
# 81  No        No
# 82  No        No
#
#                                                        FEES_OTHER  \
# 80  Clothing labelling fee, specialized wheelchairs, hairdressing
# 81  Clothing labelling fee, specialized wheelchairs, hairdressing
# 82  Clothing labelling fee, specialized wheelchairs, hairdressing
#
#     BEDS_PRIVATE  BEDS_PUBLIC  BEDS_TOTAL  ROOMS_PRIVATE  ROOMS_SEMI  \
# 80  0             100          100         100            0
# 81  0             82           82          70             6
# 82  0             19           19          19             0
#
#     ROOMS_MULTI  COMPLAINTS  SUB_COMPLAINTS  INCIDENT_OUTBREAK  \
# 80  0            2.0         1.0             1.0
# 81  0            1.0         1.0             0.0
# 82  0           NaN         NaN             NaN
#
#     INCIDENT_ABUSE  INCIDENT_FALL  INCIDENT_POISON  INCIDENT_MEDICATION  \
# 80  5.0             12.0           0.0              0.0
# 81  0.0             9.0            0.0              0.0
# 82 NaN             NaN            NaN              NaN
#
#     INCIDENT_WANDERING  INCIDENT_INJURY  INCIDENT_AGGRESSION  \
# 80  0.0                 2.0              6.0
# 81  2.0                 1.0              0.0
# 82 NaN                 NaN              NaN
#
#     INCIDENT_OUTBREAK_100  INCIDENT_ABUSE_100  INCIDENT_FALL_100  \
# 80  1.0                    5.0                 12.0
# 81  0.0                    0.0                 11.0
# 82 NaN                    NaN                 NaN
#
#     INCIDENT_POISON_100  INCIDENT_MEDICATION_100  INCIDENT_WANDERING_100  \
# 80  0.0                  0.0                      0.0
# 81  0.0                  0.0                      2.4
# 82 NaN                  NaN                      NaN
#
#     INCIDENT_INJURY_100  INCIDENT_AGGRESSION_100  ADVERSE_EVENT   AGE  FEMALE  \
# 80  2.0                  6.0                     NaN             87.0  66.8
# 81  1.2                  0.0                     NaN             84.0  65.8
# 82 NaN                  NaN                      NaN             80.0  27.5
#
#     AGE_85_PLUS  AGE_UNDER_65  STAY_LENGTH  DEPRESSION  ADL_DEPENDENT  \
# 80  63.7         0.8          NaN           16.7        43.8
# 81  54.8         2.6          NaN           19.2        43.3
# 82  29.7         1.4           273.0        7.8         19.5
#
#     CPS_SEVERE  DEMENTIA  ABS_PHYS_ABUSIVE  ISE  ISE_LOW   CMI  THERAPY_PT  \
# 80  48.7        57.8      11.4              2.2  58.5     0.57  9.2
# 81  32.9        71.6      11.3              2.9  45.4     0.59  9.8
# 82  66.2        85.7      19.5              2.0  58.4     0.54  1.3
#
#     THERAPY_RT  THERAPY_OT  MEDS_DEPRESSION  MEDS_ANTIPSYCHOTICS  RESTRAINTS  \
# 80  84.3        0.0         36.6             25.4                 12.6
# 81  67.7        3.7         45.7             25.8                 14.1
# 82  59.7        0.0         76.6             75.4                 9.1
#
#                              WEBPAGE  \
# 80  http://www.fairhaven.bc.ca/care/
# 81  http://www.fairhaven.bc.ca/care/
# 82  http://www.fairhaven.bc.ca/care/
#
#                                                                                        SURVEY_URL  \
# 80  https://surveybcseniors.org/carehomeresults/the-fair-haven-united-church-home-burnaby-fha/
# 81  https://surveybcseniors.org/carehomeresults/the-fair-haven-united-church-home-vancouver-vcha/
# 82  https://surveybcseniors.org/carehomeresults/the-fair-haven-united-church-home-vancouver-vcha/
#
#    MISSING_SURVEY CONTRACTED_NURSING CONTRACTED_CARE_AIDES  \
# 80  NaN            No                 No
# 81  NaN            No                 No
# 82  NaN            No                 No
#
#    CONTRACTED_HOUSEKEEPING CONTRACTED_PLANT PER_DIEM_LASTYR  \
# 80  No                      No               $197.98
# 81  No                      No               $199.74
# 82  No                      No               $281.61
#
#    PER_DIEM_CURRENTYR  INSPECTIONS  INFRACTIONS  INFRACTIONS_LICENSING  \
# 80  $205.01            3.0          5.0          0.0
# 81  $213.24            3.0          8.0          0.0
# 82  $272.35           NaN          NaN          NaN
#
#     INFRACTIONS_FACILITY  INFRACTIONS_STAFFING  INFRACTIONS_POLICY  \
# 80  1.0                   0.0                   1.0
# 81  1.0                   1.0                   2.0
# 82 NaN                   NaN                   NaN
#
#     INFRACTIONS_CARE  INFRACTIONS_DISEASE  INFRACTIONS_FOOD  \
# 80  0.0               1.0                  0.0
# 81  4.0               0.0                  0.0
# 82 NaN               NaN                  NaN
#
#     INFRACTIONS_MEDICATION  INFRACTIONS_PROGRAM  INFRACTIONS_REPORTING  \
# 80  0.0                     0.0                  1.0
# 81  0.0                     0.0                  0.0
# 82 NaN                     NaN                  NaN
#
#     INFRACTIONS_RIGHTS  INFRACTIONS_OTHER   latitude   longitude  \
# 80  1.0                 0.0                49.215270 -123.005906
# 81  0.0                 0.0                49.225452 -123.036584
# 82 NaN                 NaN                 49.225452 -123.036584
#
#                              cleaned_name Facility Name  \
# 80  fair haven - burnaby                   NaN
# 81  fair haven - vancouver                 NaN
# 82  fair haven - vancouver - special unit  NaN
#
#     Total Confirmed Cases  Total Deaths  outbreak
# 80  0.0                    0.0           0
# 81  0.0                    0.0           0
# 82  0.0                    0.0           0

# %%
# Add rows with new homes that have been merged with special units
# Duplicate the row
ltc.loc[297] = ltc.iloc[109] # For Harmony Court
ltc.loc[298] = ltc.iloc[15] # For Berkley
ltc.loc[299] = ltc.iloc[81] # For Fair Haven - Vancouver

# Adjust values in the new row
# Sum beds/room values from the original rows
ls = ['BEDS_TOTAL', 'ROOMS_PRIVATE', 'ROOMS_SEMI', 'ROOMS_MULTI',
      'BEDS_PRIVATE', 'BEDS_PUBLIC', 'Total Confirmed Cases', 'Total Deaths']

for each in ls:
    ltc.loc[297, each] = ltc.iloc[109][each] + ltc.iloc[110][each]
    ltc.loc[298, each] = ltc.iloc[15][each] + ltc.iloc[16][each]
    ltc.loc[299, each] = ltc.iloc[81][each] + ltc.iloc[82][each]


# Compute a weighted average for the DCH and demographic predictors    
ls = ['DCH_NURSE_LASTYR', 'DCH_ALLIED_LASTYR', 'DCH_TOTAL_LASTYR', 
      'DCH_NURSE_CURRENTYR', 'DCH_ALLIED_CURRENTYR', 'DCH_TOTAL_CURRENTYR', 
      'AGE', 'FEMALE', 'AGE_85_PLUS', 'AGE_UNDER_65', 'STAY_LENGTH',
      'DEPRESSION', 'ADL_DEPENDENT', 'CPS_SEVERE', 'DEMENTIA',
      'ABS_PHYS_ABUSIVE', 'ISE', 'ISE_LOW', 'CMI', 'THERAPY_PT',
      'THERAPY_RT', 'THERAPY_OT', 'MEDS_DEPRESSION',
      'MEDS_ANTIPSYCHOTICS', 'RESTRAINTS']    

for each in ls:
    ltc.loc[297, each] = ltc.iloc[109][each]*ltc.iloc[109]['BEDS_TOTAL']/ltc.iloc[297]['BEDS_TOTAL'] + ltc.iloc[110][each]*ltc.iloc[110]['BEDS_TOTAL']/ltc.iloc[297]['BEDS_TOTAL']
    ltc.loc[298, each] = ltc.iloc[15][each]*ltc.iloc[15]['BEDS_TOTAL']/ltc.iloc[298]['BEDS_TOTAL'] + ltc.iloc[16][each]*ltc.iloc[16]['BEDS_TOTAL']/ltc.iloc[298]['BEDS_TOTAL']
    ltc.loc[299, each] = ltc.iloc[81][each]*ltc.iloc[81]['BEDS_TOTAL']/ltc.iloc[299]['BEDS_TOTAL'] + ltc.iloc[82][each]*ltc.iloc[82]['BEDS_TOTAL']/ltc.iloc[299]['BEDS_TOTAL']
    
# Drop the original rows pre-merge
ltc = ltc.drop([ltc.index[109] , ltc.index[110], 
                        ltc.index[15] , ltc.index[16],
                        ltc.index[81], ltc.index[82]])

ltc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 0 to 299
# Columns: 108 entries, FACILITY_NAME to outbreak
# dtypes: float64(62), int64(7), object(39)
# memory usage: 250.4+ KB

# %%
ltc[ltc['FACILITY_NAME'].str.contains('Special Unit', regex=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [FACILITY_NAME, HCC_CODE, HLTH_AUTH, OWNERSHIP, STREET_ADDRESS, CITY, POSTAL, PHONE, OPERATOR_NAME, OPEN_DATE, COUNCIL, MEETINGS_HELD, PARKING_COSTS, REGULATION, ACCRED_STATUS, ACCRED_EXPIRY, COMPLAINT_CONTACT, COMPLAINT_PHONE, SPENDING_ACCOUNT, FOOD_SERVICE, FOOD_PREP, FOOD_COST_LASTYR, FOOD_COST_CURRENTYR, LANGUAGES, DCH_NURSE_LASTYR, DCH_ALLIED_LASTYR, DCH_TOTAL_LASTYR, DCH_NURSE_CURRENTYR, DCH_ALLIED_CURRENTYR, DCH_TOTAL_CURRENTYR, FEES_CABLE, FEES_TELE, FEES_INTERNET, FEES_OTHER, BEDS_PRIVATE, BEDS_PUBLIC, BEDS_TOTAL, ROOMS_PRIVATE, ROOMS_SEMI, ROOMS_MULTI, COMPLAINTS, SUB_COMPLAINTS, INCIDENT_OUTBREAK, INCIDENT_ABUSE, INCIDENT_FALL, INCIDENT_POISON, INCIDENT_MEDICATION, INCIDENT_WANDERING, INCIDENT_INJURY, INCIDENT_AGGRESSION, INCIDENT_OUTBREAK_100, INCIDENT_ABUSE_100, INCIDENT_FALL_100, INCIDENT_POISON_100, INCIDENT_MEDICATION_100, INCIDENT_WANDERING_100, INCIDENT_INJURY_100, INCIDENT_AGGRESSION_100, ADVERSE_EVENT, AGE, FEMALE, AGE_85_PLUS, AGE_UNDER_65, STAY_LENGTH, DEPRESSION, ADL_DEPENDENT, CPS_SEVERE, DEMENTIA, ABS_PHYS_ABUSIVE, ISE, ISE_LOW, CMI, THERAPY_PT, THERAPY_RT, THERAPY_OT, MEDS_DEPRESSION, MEDS_ANTIPSYCHOTICS, RESTRAINTS, WEBPAGE, SURVEY_URL, MISSING_SURVEY, CONTRACTED_NURSING, CONTRACTED_CARE_AIDES, CONTRACTED_HOUSEKEEPING, CONTRACTED_PLANT, PER_DIEM_LASTYR, PER_DIEM_CURRENTYR, INSPECTIONS, INFRACTIONS, INFRACTIONS_LICENSING, INFRACTIONS_FACILITY, INFRACTIONS_STAFFING, INFRACTIONS_POLICY, INFRACTIONS_CARE, INFRACTIONS_DISEASE, INFRACTIONS_FOOD, INFRACTIONS_MEDICATION, INFRACTIONS_PROGRAM, INFRACTIONS_REPORTING, INFRACTIONS_RIGHTS, ...]
# Index: []

# %%
len(ltc)
# 248 homes have 0 multi-rooms
# ltc['ROOMS_MULTI'].value_counts()

# 128 homes have 0 semi-rooms
# ltc['ROOMS_SEMI'].value_counts()
# Out:
# 294

# %%
ltc.columns.values
# Out:
# array(['FACILITY_NAME', 'HCC_CODE', 'HLTH_AUTH', 'OWNERSHIP',
#        'STREET_ADDRESS', 'CITY', 'POSTAL', 'PHONE', 'OPERATOR_NAME',
#        'OPEN_DATE', 'COUNCIL', 'MEETINGS_HELD', 'PARKING_COSTS',
#        'REGULATION', 'ACCRED_STATUS', 'ACCRED_EXPIRY',
#        'COMPLAINT_CONTACT', 'COMPLAINT_PHONE', 'SPENDING_ACCOUNT',
#        'FOOD_SERVICE', 'FOOD_PREP', 'FOOD_COST_LASTYR',
#        'FOOD_COST_CURRENTYR', 'LANGUAGES', 'DCH_NURSE_LASTYR',
#        'DCH_ALLIED_LASTYR', 'DCH_TOTAL_LASTYR', 'DCH_NURSE_CURRENTYR',
#        'DCH_ALLIED_CURRENTYR', 'DCH_TOTAL_CURRENTYR', 'FEES_CABLE',
#        'FEES_TELE', 'FEES_INTERNET', 'FEES_OTHER', 'BEDS_PRIVATE',
#        'BEDS_PUBLIC', 'BEDS_TOTAL', 'ROOMS_PRIVATE', 'ROOMS_SEMI',
#        'ROOMS_MULTI', 'COMPLAINTS', 'SUB_COMPLAINTS', 'INCIDENT_OUTBREAK',
#        'INCIDENT_ABUSE', 'INCIDENT_FALL', 'INCIDENT_POISON',
#        'INCIDENT_MEDICATION', 'INCIDENT_WANDERING', 'INCIDENT_INJURY',
#        'INCIDENT_AGGRESSION', 'INCIDENT_OUTBREAK_100',
#        'INCIDENT_ABUSE_100', 'INCIDENT_FALL_100', 'INCIDENT_POISON_100',
#        'INCIDENT_MEDICATION_100', 'INCIDENT_WANDERING_100',
#        'INCIDENT_INJURY_100', 'INCIDENT_AGGRESSION_100', 'ADVERSE_EVENT',
#        'AGE', 'FEMALE', 'AGE_85_PLUS', 'AGE_UNDER_65', 'STAY_LENGTH',
#        'DEPRESSION', 'ADL_DEPENDENT', 'CPS_SEVERE', 'DEMENTIA',
#        'ABS_PHYS_ABUSIVE', 'ISE', 'ISE_LOW', 'CMI', 'THERAPY_PT',
#        'THERAPY_RT', 'THERAPY_OT', 'MEDS_DEPRESSION',
#        'MEDS_ANTIPSYCHOTICS', 'RESTRAINTS', 'WEBPAGE', 'SURVEY_URL',
#        'MISSING_SURVEY', 'CONTRACTED_NURSING', 'CONTRACTED_CARE_AIDES',
#        'CONTRACTED_HOUSEKEEPING', 'CONTRACTED_PLANT', 'PER_DIEM_LASTYR',
#        'PER_DIEM_CURRENTYR', 'INSPECTIONS', 'INFRACTIONS',
#        'INFRACTIONS_LICENSING', 'INFRACTIONS_FACILITY',
#        'INFRACTIONS_STAFFING', 'INFRACTIONS_POLICY', 'INFRACTIONS_CARE',
#        'INFRACTIONS_DISEASE', 'INFRACTIONS_FOOD',
#        'INFRACTIONS_MEDICATION', 'INFRACTIONS_PROGRAM',
#        'INFRACTIONS_REPORTING', 'INFRACTIONS_RIGHTS', 'INFRACTIONS_OTHER',
#        'latitude', 'longitude', 'cleaned_name', 'Facility Name',
#        'Total Confirmed Cases', 'Total Deaths', 'outbreak'], dtype=object)

# %% [markdown]
# # Create the Complete Dataset ltc_com
# # Adjust predictors

# %%
# ltc.dtypes
# ltc['outbreak'].value_counts()
ltc['OWNERSHIP'].value_counts()
# ltc.columns.values

# %%
ltc_com = ltc

# ROOMS_* variables
# Define binary variables for presence of semi or multi rooms
conditions = [ltc_com['ROOMS_SEMI'] == 0]
outputs = [0]
ltc_com['rooms_semi_binary'] = np.select(conditions, outputs, 1)

conditions = [ltc_com['ROOMS_MULTI'] == 0]
outputs = [0]
ltc_com['rooms_multi_binary'] = np.select(conditions, outputs, 1)

# Define a binary variable for rooms_shared
conditions = [ltc_com['ROOMS_SEMI'].eq(0) & ltc_com['ROOMS_MULTI'].eq(0)]
outputs = [0]
ltc_com['rooms_shared'] = np.select(conditions, outputs, 1)

# Council variable
# Define new variables for resident and family councils
conditions = [ltc_com['COUNCIL'].str.contains('Resident', regex=False, na=False)]
outputs = [1]
ltc_com['resident_council'] = np.select(conditions, outputs, 0)

conditions = [ltc_com['COUNCIL'].str.contains('Family', regex=False, na=False)]
outputs = [1]
ltc_com['family_council'] = np.select(conditions, outputs, 0)

# Define a binary variable for the presence of resident AND family councils
conditions = [ltc_com['COUNCIL'].str.contains('Resident', regex=False, na=False) & ltc_com['COUNCIL'].str.contains('Family', regex=False, na=False)]
outputs = [1]
ltc_com['res_fam_council'] = np.select(conditions, outputs, 0)

# # We see that about 2/3 of the homes have 0 private beds
# ltc_com['BEDS_PRIVATE'].value_counts()

# Define proportion of private vs public beds
ltc_com['beds_privateprop'] = ltc_com['BEDS_PRIVATE']/ltc_com['BEDS_TOTAL']

# Define a binary variable for private beds
conditions = [ltc_com['BEDS_PRIVATE'] == 0]
outputs = [0]
ltc_com['beds_privatebinary'] = np.select(conditions, outputs, 1)

# # Define new variables for REGULATION
# conditions = [ltc_com['REGULATION'].str.contains('Hospital', regex=False, na=False)]
# outputs = [1]
# ltc_com['hospital_act'] = np.select(conditions, outputs, 0)

# conditions = [ltc_com['REGULATION'].str.contains('Community', regex=False, na=False)]
# outputs = [1]
# ltc_com['community_act'] = np.select(conditions, outputs, 0)

# Adjust datatypes for complaints/incident data
# Complaints 
    
# Note that Northern Health does not report complaints for facilities licensed under the Hospital Act
# There are 11 homes without complaints/sub-complaints data, 10 of these are in NH (Hospital Act)
# There are 4 homes with suppressed complaints/sub-complaints data 
# Consider categorizing complaints as 0, >0, unknown
    # There are 139 homes with 0 complaints
#     'COMPLAINTS', 
    
    # There are 201 homes with 0 sub-complaints
#     'SUB_COMPLAINTS', 

# Define complaints/sub_complaints per 100 beds values
ltc_com['complaints_100'] = ltc_com['COMPLAINTS']/ltc_com['BEDS_TOTAL']*100
ltc_com['sub_complaints_100'] = ltc_com['SUB_COMPLAINTS']/ltc_com['BEDS_TOTAL']*100

# Incident
# Sum incidents data
ltc_com['incident_100sum'] = ltc_com[[
    'INCIDENT_OUTBREAK_100',
    'INCIDENT_ABUSE_100', 
    'INCIDENT_FALL_100', 
    'INCIDENT_POISON_100',
    'INCIDENT_MEDICATION_100', 
    'INCIDENT_WANDERING_100',
    'INCIDENT_INJURY_100', 
    'INCIDENT_AGGRESSION_100']].sum(axis=1)
ltc_com['incident_100sumXoutbreak'] = ltc_com[[
    'INCIDENT_ABUSE_100', 
    'INCIDENT_FALL_100', 
    'INCIDENT_POISON_100',
    'INCIDENT_MEDICATION_100', 
    'INCIDENT_WANDERING_100',
    'INCIDENT_INJURY_100', 
    'INCIDENT_AGGRESSION_100']].sum(axis=1)

# Infractions
# Define infractions/infractions_disease per 100 beds values
ltc_com['infractions_100'] = ltc_com['INFRACTIONS']/ltc_com['BEDS_TOTAL']*100
ltc_com['infractions_disease_100'] = ltc_com['INFRACTIONS_DISEASE']/ltc_com['BEDS_TOTAL']*100
ltc_com['infractions_100Xdisease'] = ltc_com['INFRACTIONS']/ltc_com['BEDS_TOTAL']*100 - ltc_com['INFRACTIONS_DISEASE']/ltc_com['BEDS_TOTAL']*100

# Ownership
# Define a binary variable for HA ownership or not
conditions = [ltc_com['OWNERSHIP'].eq('HA')]
outputs = [1]
ltc_com['ownership_HA'] = np.select(conditions, outputs, 0)

# %%
# Drop irrelevant columns
ls = [
    # DCH funded, not delivered (respresents a calculation from the HA)
    'DCH_NURSE_LASTYR',
      'DCH_ALLIED_LASTYR', 
      'DCH_TOTAL_LASTYR', 
      'DCH_NURSE_CURRENTYR',
      'DCH_ALLIED_CURRENTYR', 
      'DCH_TOTAL_CURRENTYR',
      
      'ROOMS_PRIVATE', 
      'ROOMS_SEMI',
      'ROOMS_MULTI',
    
      'COMPLAINTS', 
      'SUB_COMPLAINTS',
      
      'INCIDENT_OUTBREAK',
      'INCIDENT_ABUSE', 
      'INCIDENT_FALL', 
      'INCIDENT_POISON',
      'INCIDENT_MEDICATION', 
      'INCIDENT_WANDERING', 
      'INCIDENT_INJURY',
      'INCIDENT_AGGRESSION', 

    'INCIDENT_ABUSE_100', 
    'INCIDENT_FALL_100', 
    'INCIDENT_POISON_100',
    'INCIDENT_MEDICATION_100', 
    'INCIDENT_WANDERING_100',
    'INCIDENT_INJURY_100', 
    'INCIDENT_AGGRESSION_100',
      
      'INFRACTIONS',
      'INFRACTIONS_LICENSING', 
      'INFRACTIONS_FACILITY',
      'INFRACTIONS_STAFFING', 
      'INFRACTIONS_POLICY', 
      'INFRACTIONS_CARE',
      'INFRACTIONS_DISEASE', 
      'INFRACTIONS_FOOD',
      'INFRACTIONS_MEDICATION', 
      'INFRACTIONS_PROGRAM',
      'INFRACTIONS_REPORTING', 
      'INFRACTIONS_RIGHTS', 
      'INFRACTIONS_OTHER',
      
    'PHONE', 
    'OPERATOR_NAME', # there are 100 unique values
    'OPEN_DATE', # Unclear what this means, one entry 2009/2016, see email from Rob
    'COUNCIL',
    'MEETINGS_HELD', 
    'PARKING_COSTS',
    'ACCRED_EXPIRY',
    'COMPLAINT_CONTACT', 
    'COMPLAINT_PHONE', 
    'SPENDING_ACCOUNT',
    'FOOD_SERVICE', 
    'FOOD_PREP', 
    'FOOD_COST_LASTYR',
    'FOOD_COST_CURRENTYR', 
    'LANGUAGES', 
    'FEES_CABLE',
    'FEES_TELE', 
    'FEES_INTERNET', 
    'FEES_OTHER', 
    'BEDS_PRIVATE',
    'BEDS_PUBLIC',
    'ADVERSE_EVENT',   # 275 listed as not applicable  
    'WEBPAGE', 
    'SURVEY_URL',
    'MISSING_SURVEY',
    'CONTRACTED_NURSING',
    'CONTRACTED_CARE_AIDES',
    'CONTRACTED_HOUSEKEEPING',
    'CONTRACTED_PLANT',
    'PER_DIEM_LASTYR',
    'PER_DIEM_CURRENTYR',
    'cleaned_name', 
    'Facility Name'
]

ltc_com = ltc_com.drop(ls, axis = 1)
ltc_com.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 0 to 299
# Data columns (total 52 columns):
# FACILITY_NAME               294 non-null object
# HCC_CODE                    294 non-null object
# HLTH_AUTH                   294 non-null object
# OWNERSHIP                   294 non-null object
# STREET_ADDRESS              294 non-null object
# CITY                        294 non-null object
# POSTAL                      294 non-null object
# REGULATION                  294 non-null object
# ACCRED_STATUS               294 non-null object
# BEDS_TOTAL                  294 non-null int64
# INCIDENT_OUTBREAK_100       268 non-null float64
# AGE                         287 non-null float64
# FEMALE                      287 non-null float64
# AGE_85_PLUS                 287 non-null float64
# AGE_UNDER_65                287 non-null float64
# STAY_LENGTH                 193 non-null float64
# DEPRESSION                  287 non-null float64
# ADL_DEPENDENT               287 non-null float64
# CPS_SEVERE                  287 non-null float64
# DEMENTIA                    287 non-null float64
# ABS_PHYS_ABUSIVE            287 non-null float64
# ISE                         286 non-null float64
# ISE_LOW                     287 non-null float64
# CMI                         286 non-null float64
# THERAPY_PT                  287 non-null float64
# THERAPY_RT                  287 non-null float64
# THERAPY_OT                  287 non-null float64
# MEDS_DEPRESSION             287 non-null float64
# MEDS_ANTIPSYCHOTICS         287 non-null float64
# RESTRAINTS                  287 non-null float64
# INSPECTIONS                 294 non-null float64
# latitude                    294 non-null float64
# longitude                   294 non-null float64
# Total Confirmed Cases       294 non-null float64
# Total Deaths                294 non-null float64
# outbreak                    294 non-null int64
# rooms_semi_binary           294 non-null int64
# rooms_multi_binary          294 non-null int64
# rooms_shared                294 non-null int64
# resident_council            294 non-null int64
# family_council              294 non-null int64
# res_fam_council             294 non-null int64
# beds_privateprop            294 non-null float64
# beds_privatebinary          294 non-null int64
# complaints_100              279 non-null float64
# sub_complaints_100          279 non-null float64
# incident_100sum             294 non-null float64
# incident_100sumXoutbreak    294 non-null float64
# infractions_100             294 non-null float64
# infractions_disease_100     294 non-null float64
# infractions_100Xdisease     294 non-null float64
# ownership_HA                294 non-null int64
# dtypes: float64(33), int64(10), object(9)
# memory usage: 121.7+ KB

# %%
import missingno as msno
msno.matrix(ltc_com)

# %%
ltc_com[ltc_com['AGE'].isnull()]

# %%
# Export the complete dataset
ltc_com.to_csv(r'../data/BC/bc_ltc_complete_sep18.csv', index = False)

# %% [markdown]
# # Create selected variables dataset ltc_sel

# %%
ltc_sel = ltc_com
ltc_sel = ltc_sel.dropna(axis=1)
ltc_sel.info()
# ltc_sel.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 0 to 299
# Data columns (total 30 columns):
# FACILITY_NAME               294 non-null object
# HCC_CODE                    294 non-null object
# HLTH_AUTH                   294 non-null object
# OWNERSHIP                   294 non-null object
# STREET_ADDRESS              294 non-null object
# CITY                        294 non-null object
# POSTAL                      294 non-null object
# REGULATION                  294 non-null object
# ACCRED_STATUS               294 non-null object
# BEDS_TOTAL                  294 non-null int64
# INSPECTIONS                 294 non-null float64
# latitude                    294 non-null float64
# longitude                   294 non-null float64
# Total Confirmed Cases       294 non-null float64
# Total Deaths                294 non-null float64
# outbreak                    294 non-null int64
# rooms_semi_binary           294 non-null int64
# rooms_multi_binary          294 non-null int64
# rooms_shared                294 non-null int64
# resident_council            294 non-null int64
# family_council              294 non-null int64
# res_fam_council             294 non-null int64
# beds_privateprop            294 non-null float64
# beds_privatebinary          294 non-null int64
# incident_100sum             294 non-null float64
# incident_100sumXoutbreak    294 non-null float64
# infractions_100             294 non-null float64
# infractions_disease_100     294 non-null float64
# infractions_100Xdisease     294 non-null float64
# ownership_HA                294 non-null int64
# dtypes: float64(11), int64(10), object(9)
# memory usage: 71.2+ KB

# %%
ltc_sel.columns.values
# Out:
# array(['FACILITY_NAME', 'HCC_CODE', 'HLTH_AUTH', 'OWNERSHIP',
#        'STREET_ADDRESS', 'CITY', 'POSTAL', 'REGULATION', 'ACCRED_STATUS',
#        'BEDS_TOTAL', 'INSPECTIONS', 'latitude', 'longitude',
#        'Total Confirmed Cases', 'Total Deaths', 'outbreak',
#        'rooms_semi_binary', 'rooms_multi_binary', 'rooms_shared',
#        'resident_council', 'family_council', 'res_fam_council',
#        'beds_privateprop', 'beds_privatebinary', 'incident_100sum',
#        'incident_100sumXoutbreak', 'infractions_100',
#        'infractions_disease_100', 'infractions_100Xdisease',
#        'ownership_HA'], dtype=object)

# %%
# Reorder columns in df
# Remove variables known to be missing (commented out)
# Note that incident data are missing for Hospital Act facilities in VIHA

ltc_sel = ltc_sel[[
        'outbreak',
        'Total Confirmed Cases', 
        'Total Deaths',
        'FACILITY_NAME',
        'HCC_CODE',
        'HLTH_AUTH',
        'OWNERSHIP',
        'STREET_ADDRESS',
        'CITY',
        'POSTAL',
        'REGULATION',
        'ACCRED_STATUS',
        'BEDS_TOTAL',
        'INSPECTIONS',
        'rooms_semi_binary', 
        'rooms_multi_binary', 
        'rooms_shared',
        'resident_council', 
        'family_council', 
        'res_fam_council',
        'beds_privateprop', 
        'beds_privatebinary', 
#         'incident_100sum',
#         'incident_100sum-outbreak',
#         'incident_100sumXoutbreak'
        'infractions_100',
        'infractions_disease_100',
        'infractions_100Xdisease',
        'ownership_HA',
        'latitude',
        'longitude'
]]
ltc_sel.info()
# ltc_sel.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 0 to 299
# Data columns (total 28 columns):
# outbreak                   294 non-null int64
# Total Confirmed Cases      294 non-null float64
# Total Deaths               294 non-null float64
# FACILITY_NAME              294 non-null object
# HCC_CODE                   294 non-null object
# HLTH_AUTH                  294 non-null object
# OWNERSHIP                  294 non-null object
# STREET_ADDRESS             294 non-null object
# CITY                       294 non-null object
# POSTAL                     294 non-null object
# REGULATION                 294 non-null object
# ACCRED_STATUS              294 non-null object
# BEDS_TOTAL                 294 non-null int64
# INSPECTIONS                294 non-null float64
# rooms_semi_binary          294 non-null int64
# rooms_multi_binary         294 non-null int64
# rooms_shared               294 non-null int64
# resident_council           294 non-null int64
# family_council             294 non-null int64
# res_fam_council            294 non-null int64
# beds_privateprop           294 non-null float64
# beds_privatebinary         294 non-null int64
# infractions_100            294 non-null float64
# infractions_disease_100    294 non-null float64
# infractions_100Xdisease    294 non-null float64
# ownership_HA               294 non-null int64
# latitude                   294 non-null float64
# longitude                  294 non-null float64
# dtypes: float64(9), int64(10), object(9)
# memory usage: 66.6+ KB

# %%
# Export the selected dataset
ltc_sel.to_csv(r'../data/BC/bc_ltc_selected_sep18.csv', index = False)
