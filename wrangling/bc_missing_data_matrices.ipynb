# %%
import pandas as pd
import missingno as msno

# %%
data = pd.read_csv('../data/BC/bc_ltc_complete.csv')

msno.matrix(data[sect])

# %%
msno.matrix(data[dch])

# %%
sect = data.columns[19:37].to_list()
for i in data.columns[56:70]:
    sect.append(i)

# %%
dch = data.columns[9:15]

# %%
dch
# Out:
# Index(['DCH_NURSE_LASTYR', 'DCH_ALLIED_LASTYR', 'DCH_TOTAL_LASTYR',
#        'DCH_NURSE_CURRENTYR', 'DCH_ALLIED_CURRENTYR', 'DCH_TOTAL_CURRENTYR'],
#       dtype='object')
