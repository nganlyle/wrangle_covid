# %%
import pandas as pd

# %%
aug10 = pd.read_csv('../data/bc_ltc_scraped.csv')
nora = pd.read_csv('../data/Deaths in Residential Care in Canada by facility - Institutions.csv',  skiprows=[0,1])

# %%
aug10.head()
# Out:
#    Unnamed: 0 datedeclared/restrictionsimposed                     facility  \
# 0           0                    July 31, 2020                   Dania Home
# 1           1                   August 4, 2020  Maple Ridge Seniors Village
# 2           2                   August 6, 2020                  Derby Manor
# 3           3                   August 7, 2020          George Derby Centre
# 4           4                   August 8, 2020       New Vista Care Society
#
#   facilitytype outbreaktype health_authority address
# 0  Residential     COVID-19           fraser     NaN
# 1  Residential     COVID-19           fraser     NaN
# 2  Residential     COVID-19           fraser     NaN
# 3  Residential     COVID-19           fraser     NaN
# 4  Residential     COVID-19           fraser     NaN

# %%
nora_bc = nora.loc[nora['Prov.'] == 'BC']

# %%
list(set(nora_bc.FACILITY_NAME.unique()) - set(BC_cases.FACILITY_NAME.unique()))
# Out:
#                                        Facility         Location Prov.  \
# 82                                Langley Lodge          Langley    BC
# 117                     Lynn Valley Care Centre  North Vancouver    BC
# 163    Holy Family Hospital long term care unit        Vancouver    BC
# 182                                   Haro Park        Vancouver    BC
# 194                     Royal Arch Masonic Home        Vancouver    BC
# 244           Lions Gate Hospital (Unit 6 East)        Vancouver    BC
# 292                         Berkley Care Centre  North Vancouver    BC
# 324                        Dufferin Care Centre        Coquitlam    BC
# 355        Four LTC homes in Vancouver - July 6        Vancouver    BC
# 365                      Amica Edgemont Village  North Vancouver    BC
# 366  Ridge Meadows Hospital (Rehab and Unit 3W)      Maple Ridge    BC
# 367                     Swedish Assisted Living        Vancouver    BC
# ...
