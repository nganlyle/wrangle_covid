# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
# Import the census data
df = pd.read_csv('98-401-X2016058_English_CSV_data.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316827 entries, 0 to 316826
# Data columns (total 14 columns):
# CENSUS_YEAR                                    316827 non-null int64
# GEO_CODE (POR)                                 316827 non-null int64
# GEO_LEVEL                                      316827 non-null int64
# GEO_NAME                                       316827 non-null object
# GNR                                            316827 non-null float64
# GNR_LF                                         316827 non-null float64
# DATA_QUALITY_FLAG                              316827 non-null int64
# ALT_GEO_CODE                                   316827 non-null int64
# DIM: Profile of Health Regions (2247)          316827 non-null object
# Member ID: Profile of Health Regions (2247)    316827 non-null int64
# Notes: Profile of Health Regions (2247)        31725 non-null float64
# Dim: Sex (3): Member ID: [1]: Total - Sex      316827 non-null object
# ...

# %%
# Filter for Ontario data
listofLHIN = [3501, 3502, 3503, 3504, 3505, 3506, 3507, 3508, 3509, 3510, 3511, 3512, 3513, 
               3514]
listofPHU = [3526, 3527, 3530, 3531, 3533, 3534, 3535, 3536, 3537, 3538, 3539, 3540, 
               3541, 3542, 3543, 3544, 3546, 3547, 3549, 3551, 3552, 3553, 3554, 3555, 3556, 
               3557, 3558, 3560, 3561, 3562, 3563, 3565, 3566, 3568, 3570, 3595]

print(len(listofLHIN), len(listofPHU))
# Out:
# 14 36

# %%
# Filter for Ontario PHU data
listofLHIN = [3501, 3502, 3503, 3504, 3505, 3506, 3507, 3508, 3509, 3510, 3511, 3512, 3513, 
               3514]
listofPHU = [3526, 3527, 3530, 3531, 3533, 3534, 3535, 3536, 3537, 3538, 3539, 3540, 
               3541, 3542, 3543, 3544, 3546, 3547, 3549, 3551, 3552, 3553, 3554, 3555, 3556, 
               3557, 3558, 3560, 3561, 3562, 3563, 3565, 3566, 3568, 3570, 3595]

df = df[df['GEO_CODE (POR)'].isin(listofPHU)]
df.info()
df['GEO_CODE (POR)'].nunique()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80892 entries, 123585 to 204476
# Data columns (total 14 columns):
# CENSUS_YEAR                                    80892 non-null int64
# GEO_CODE (POR)                                 80892 non-null int64
# GEO_LEVEL                                      80892 non-null int64
# GEO_NAME                                       80892 non-null object
# GNR                                            80892 non-null float64
# GNR_LF                                         80892 non-null float64
# DATA_QUALITY_FLAG                              80892 non-null int64
# ALT_GEO_CODE                                   80892 non-null int64
# DIM: Profile of Health Regions (2247)          80892 non-null object
# Member ID: Profile of Health Regions (2247)    80892 non-null int64
# Notes: Profile of Health Regions (2247)        8100 non-null float64
# Dim: Sex (3): Member ID: [1]: Total - Sex      80892 non-null object
# ...

# %%
# Create new columns with PHU names
df['phu_eng'] = df['GEO_NAME'].str.split('/').str[0]
df['phu_fr'] = df['GEO_NAME'].str.split('/').str[1]
df.tail()
# Out:
#         CENSUS_YEAR  GEO_CODE (POR)  GEO_LEVEL  \
# 204472  2016         3595            2
# 204473  2016         3595            2
# 204474  2016         3595            2
# 204475  2016         3595            2
# 204476  2016         3595            2
#
#                                                                              GEO_NAME  \
# 204472  City of Toronto Health Unit / Circonscription sanitaire de la cité de Toronto
# 204473  City of Toronto Health Unit / Circonscription sanitaire de la cité de Toronto
# 204474  City of Toronto Health Unit / Circonscription sanitaire de la cité de Toronto
# 204475  City of Toronto Health Unit / Circonscription sanitaire de la cité de Toronto
# 204476  City of Toronto Health Unit / Circonscription sanitaire de la cité de Toronto
#
#         GNR  GNR_LF  DATA_QUALITY_FLAG  ALT_GEO_CODE  \
# 204472  3.8  4.9     0                  3595
# 204473  3.8  4.9     0                  3595
# 204474  3.8  4.9     0                  3595
# ...

# %%
df[df['Member ID: Profile of Health Regions (2247)']==41]
# Out:
#         CENSUS_YEAR  GEO_CODE (POR)  GEO_LEVEL  \
# 123625  2016         3526            2
# 125872  2016         3527            2
# 128119  2016         3530            2
# 130366  2016         3531            2
# 132613  2016         3533            2
# 134860  2016         3534            2
# 137107  2016         3535            2
# 139354  2016         3536            2
# 141601  2016         3537            2
# 143848  2016         3538            2
# 146095  2016         3539            2
# 148342  2016         3540            2
# 150589  2016         3541            2
# 152836  2016         3542            2
# 155083  2016         3543            2
# 157330  2016         3544            2
# 159577  2016         3546            2
# 161824  2016         3547            2
# 164071  2016         3549            2
# 166318  2016         3551            2
# 168565  2016         3552            2
# 170812  2016         3553            2
# 173059  2016         3554            2
# ...

# %%
# Import list of variables of interest
char = pd.read_csv('selected_variables.csv', header=None)
char.info()

char[1] = char[1].map(lambda x: x.lstrip(' '))
char[1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
# 0    35 non-null int64
# 1    35 non-null object
# dtypes: int64(1), object(1)
# memory usage: 640.0+ bytes
# 0     Population density per square kilometre
# 1     15 to 64 years
# 2     65 years and over
# 3     Median age of the population (6)
# 4     Average household size
# 5     Median total income of households in 2015 ($)
# 6     Median after-tax income of households in 2015 ($)
# 7     Total - Occupied private dwellings by structural type of dwelling - 100% data (7)
# 8     Single-detached house
# 9     Total - Marital status for the population aged 15 years and over - 100% data (11)
# 10    Married or living common law
# 11    Not married and not living common law
# 12    Total - Private households by tenure - 25% sample data (156)
# 13    Owner
# 14    Renter
# 15    Total - Private households by housing suitability - 25% sample data (161)
# 16    Suitable
# ...

# %%
# Subset the data
listofid = char[0].to_list()
subset = df.loc[df['Member ID: Profile of Health Regions (2247)'].isin(listofid)]  
subset = subset.reset_index()
subset.info()
subset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 17 columns):
# index                                          1260 non-null int64
# CENSUS_YEAR                                    1260 non-null int64
# GEO_CODE (POR)                                 1260 non-null int64
# GEO_LEVEL                                      1260 non-null int64
# GEO_NAME                                       1260 non-null object
# GNR                                            1260 non-null float64
# GNR_LF                                         1260 non-null float64
# DATA_QUALITY_FLAG                              1260 non-null int64
# ALT_GEO_CODE                                   1260 non-null int64
# DIM: Profile of Health Regions (2247)          1260 non-null object
# Member ID: Profile of Health Regions (2247)    1260 non-null int64
# Notes: Profile of Health Regions (2247)        396 non-null float64
# ...

# %%
# Drop columns that are not needed
listofcols = ['index', 'CENSUS_YEAR', 'GEO_LEVEL', 'GEO_NAME', 'GNR','GNR_LF', 'DATA_QUALITY_FLAG', 'ALT_GEO_CODE', 
              'Dim: Sex (3): Member ID: [2]: Male', 'Dim: Sex (3): Member ID: [3]: Female']

subset.drop(listofcols, axis = 1, inplace = True)
subset["Dim: Sex (3): Member ID: [1]: Total - Sex"] = pd.to_numeric(subset["Dim: Sex (3): Member ID: [1]: Total - Sex"])
subset.head()
# Out:
#    GEO_CODE (POR)  \
# 0  3526
# 1  3526
# 2  3526
# 3  3526
# 4  3526
#
#                                            DIM: Profile of Health Regions (2247)  \
# 0  Population density per square kilometre
# 1  15 to 64 years
# 2  65 years and over
# 3  Median age of the population
# 4  Total - Occupied private dwellings by structural type of dwelling - 100% data
#
#    Member ID: Profile of Health Regions (2247)  \
# 0  6
# 1  36
# 2  37
# 3  40
# 4  41
#
#    Notes: Profile of Health Regions (2247)  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3  6.0
# 4  7.0
#
#    Dim: Sex (3): Member ID: [1]: Total - Sex  \
# 0  2.7
# 1  62.3
# 2  23.7
# 3  49.1
# 4  50655.0
#
#                                phu_eng  \
# 0  The District of Algoma Health Unit
# 1  The District of Algoma Health Unit
# 2  The District of Algoma Health Unit
# 3  The District of Algoma Health Unit
# 4  The District of Algoma Health Unit
#
#                                             phu_fr
# ...

# %%
listofcols = list(subset['DIM: Profile of Health Regions (2247)'].head(35))
listofcols
# Out:
# ['Population density per square kilometre',
#  '15 to 64 years',
#  '65 years and over',
#  'Median age of the population',
#  'Total - Occupied private dwellings by structural type of dwelling - 100% data',
#  'Single-detached house',
#  'Average household size',
#  'Total - Marital status for the population aged 15 years and over - 100% data',
#  'Married or living common law',
#  'Not married and not living common law',
#  'Median total income of households in 2015 ($)',
#  'Median after-tax income of households in 2015 ($)',
#  'Total - Private households by tenure - 25% sample data',
#  'Owner',
#  'Renter',
#  'Total - Private households by number of persons per room - 25% sample data',
#  'One person or fewer per room',
#  'More than 1 person per room',
#  'Total - Private households by housing suitability - 25% sample data',
#  'Suitable',
#  'Not suitable',
# ...

# %%
# Pivot the table
table = pd.pivot_table(subset, values = 'Dim: Sex (3): Member ID: [1]: Total - Sex',
                       index = ['phu_eng', 'phu_fr', 'GEO_CODE (POR)'],
                       columns = ['DIM: Profile of Health Regions (2247)'])
table.info()
table.head()
table = table.reset_index()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 36 entries, (Brant County Health Unit ,  Circonscription sanitaire du comté de Brant, 3527) to (York Regional Health Unit ,  Circonscription sanitaire de York, 3570)
# Data columns (total 35 columns):
# 15 to 64 years                                                                                                                                                                          36 non-null float64
# 65 years and over                                                                                                                                                                       36 non-null float64
# Average household size                                                                                                                                                                  36 non-null float64
# ...

# %%
table.head()
# table.columns.values
# Out:
# DIM: Profile of Health Regions (2247)                        phu_eng  \
# 0                                      Brant County Health Unit
# 1                                      Chatham-Kent Health Unit
# 2                                      City of Hamilton Health Unit
# 3                                      City of Ottawa Health Unit
# 4                                      City of Toronto Health Unit
#
# DIM: Profile of Health Regions (2247)                                             phu_fr  \
# 0                                       Circonscription sanitaire du comté de Brant
# 1                                       Circonscription sanitaire de Chatham-Kent
# 2                                       Circonscription sanitaire de la cité de Hamilton
# 3                                       Circonscription sanitaire de la ville d'Ottawa
# 4                                       Circonscription sanitaire de la cité de Toronto
#
# ...

# %%
# Reorder the columns
listofcols = ['phu_eng', 'phu_fr', 'GEO_CODE (POR)'] + listofcols

table = table.reindex(columns=listofcols)
table.head()
# Out:
# DIM: Profile of Health Regions (2247)                        phu_eng  \
# 0                                      Brant County Health Unit
# 1                                      Chatham-Kent Health Unit
# 2                                      City of Hamilton Health Unit
# 3                                      City of Ottawa Health Unit
# 4                                      City of Toronto Health Unit
#
# DIM: Profile of Health Regions (2247)                                             phu_fr  \
# 0                                       Circonscription sanitaire du comté de Brant
# 1                                       Circonscription sanitaire de Chatham-Kent
# 2                                       Circonscription sanitaire de la cité de Hamilton
# 3                                       Circonscription sanitaire de la ville d'Ottawa
# 4                                       Circonscription sanitaire de la cité de Toronto
#
# ...

# %%
# Create new columns with proportions for the count data
table['Single-detached house prop'] = table['Single-detached house']/table['Total - Occupied private dwellings by structural type of dwelling - 100% data']
table['Married or living common law prop'] = table['Married or living common law']/table['Total - Marital status for the population aged 15 years and over - 100% data']
table['Not married and not living common law prop'] = table['Not married and not living common law']/table['Total - Marital status for the population aged 15 years and over - 100% data']

table['Owner prop'] = table ['Owner']/table['Total - Private households by tenure - 25% sample data']
table['Renter prop'] = table ['Renter']/table['Total - Private households by tenure - 25% sample data']

table['One person or fewer per room prop'] = table ['One person or fewer per room']/table['Total - Private households by number of persons per room - 25% sample data']
table['More than 1 person per room prop'] = table ['More than 1 person per room']/table['Total - Private households by number of persons per room - 25% sample data']

table['Suitable prop'] = table ['Suitable']/table['Total - Private households by housing suitability - 25% sample data']
table['Not suitable prop'] = table ['Not suitable']/table['Total - Private households by housing suitability - 25% sample data']

table['No certificate, diploma or degree prop'] = table ['No certificate, diploma or degree']/table['Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data']
table['Secondary (high) school diploma or equivalency certificate prop'] = table ['Secondary (high) school diploma or equivalency certificate']/table['Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data']
table['Postsecondary certificate, diploma or degree prop'] = table ['Postsecondary certificate, diploma or degree']/table['Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data']

table['In the labour force prop'] = table ['In the labour force']/table['Total - Population aged 15 years and over by Labour force status - 25% sample data']
table['Employed prop'] = table ['Employed']/table['In the labour force']
table['Unemployed prop'] = table ['Unemployed']/table['In the labour force']
table['Not in the labour force prop'] = table ['Not in the labour force']/table['Total - Population aged 15 years and over by Labour force status - 25% sample data']

table['Car, truck, van - as a driver prop'] = table ['Car, truck, van - as a driver']/table['Total - Main mode of commuting for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data']

table['Non-movers prop'] = table ['Non-movers']/table['Total - Mobility status 1 year ago - 25% sample data']
table['Movers prop'] = table ['Movers']/table['Total - Mobility status 1 year ago - 25% sample data']

# %%
listofcols = [
 'Total - Occupied private dwellings by structural type of dwelling - 100% data',
 'Single-detached house',
    
 'Total - Marital status for the population aged 15 years and over - 100% data',
 'Married or living common law',
 'Not married and not living common law',

 'Total - Private households by tenure - 25% sample data',
 'Owner',
 'Renter',
    
 'Total - Private households by number of persons per room - 25% sample data',
 'One person or fewer per room',
 'More than 1 person per room',
    
 'Total - Private households by housing suitability - 25% sample data',
 'Suitable',
 'Not suitable',
    
 'Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data',
 'No certificate, diploma or degree',
 'Secondary (high) school diploma or equivalency certificate',
 'Postsecondary certificate, diploma or degree',
    
 'Total - Population aged 15 years and over by Labour force status - 25% sample data',
 'In the labour force',
 'Employed',
 'Unemployed',
 'Not in the labour force',
    
 'Total - Main mode of commuting for the employed labour force aged 15 years and over in private households with a usual place of work or no fixed workplace address - 25% sample data',
 'Car, truck, van - as a driver',
    
 'Total - Mobility status 1 year ago - 25% sample data',
 'Non-movers',
 'Movers']

table.drop(listofcols, axis = 1, inplace = True)

# %%
table.head()
# Out:
# DIM: Profile of Health Regions (2247)                        phu_eng  \
# 0                                      Brant County Health Unit
# 1                                      Chatham-Kent Health Unit
# 2                                      City of Hamilton Health Unit
# 3                                      City of Ottawa Health Unit
# 4                                      City of Toronto Health Unit
#
# DIM: Profile of Health Regions (2247)                                             phu_fr  \
# 0                                       Circonscription sanitaire du comté de Brant
# 1                                       Circonscription sanitaire de Chatham-Kent
# 2                                       Circonscription sanitaire de la cité de Hamilton
# 3                                       Circonscription sanitaire de la ville d'Ottawa
# 4                                       Circonscription sanitaire de la cité de Toronto
#
# ...

# %%
table.to_csv(r'census_data.csv', index = False)
